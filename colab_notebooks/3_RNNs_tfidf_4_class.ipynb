# %% [markdown]
# ## Prepare data

# %%
from google.colab import drive
drive.mount("/content/MyDrive")
# Out:
# Mounted at /content/MyDrive

# %%
# %cp '/content/MyDrive/MyDrive/Colab Notebooks/Fake news detection/Data/data_clean_4_class.pkl' '/content'

# %%
import pandas as pd
pd.set_option('max_colwidth', 200)

data = pd.read_pickle('/content/data_clean_4_class.pkl')
# data = data[data['Label'] != 'Undetermined']
data
# Out:
#                                                                                                                                                                                                       Content  \
# 0     bắt_cóc trục_xuất đừng chánh_trị_gia giàu hứa nhân_đạo ký thương_ước quốc_gia tôn_trọng nhân_quyền đồng_bào trường_hợp nguyễn_quang hồng nhân trịnh thuý hạnh nhà_nước cộng_hoà liên_bang đức bắt ch...
# 1     dâm tặc viện phó đầu_sai vũ nhôm tràn_ngập báo mạng gọi hình buồn_nôn quyền_thế dâm tặc hưu địa_phương ngang_nhiên trò dâm_ô đồi_bại trẻ_em tưởng_tượng đương_chức trò đồi_bại làm_việc sinh_sống xả...
# 2     kỷ hợi dung_dưỡng tự_chủ dân_tộc v việt_nam chính_thức kỷ hợi âm_lịch việt ngô tiên_vương đánh_đuổi tan giặc nam hán nhà_nước việt_nam độc_lập chủ độc_lập tự_chủ xưng_vương kinh_đô cổ loa phong ch...
# 3     lật chiến thư chỉ_thị nguyễn thị kim_ngân cam_kết vành_đai đường ngân chân_thành bày_tỏ xu_nịnh hoàng_đế tập sắp_xếp kim_ngân leo tân_thái_thú hồn hoa xác việt tương_lai câu kinh_kệ quen_thuộc kế_...
# 4     màu cờ linh_hồn tổ_quốc bảo giang tự_do nhân_phẩm nhân_quyền công_dân luật_pháp bảo_vệ tôn_trọng công_dân coi tội tuyên_án bạo_hành cơ_quan trách_nhiệm xã_hội nhân_bản tiếng súng đùng chát phá làn...
# ...                                                                                                                                                                                                       ...
# 1294  kiên_giang miễn_nhiệm đại_biểu hđnd hà văn phúc bị_cáo buộc tham_nhũng hà văn phúc nguyên giám_đốc sở y_tế kiên_giang miễn_nhiệm đại_biểu hđnd tỉnh kiên_giang kỳ họp hậu_quả sai_phạm nghiêm_trọng ...
# 1295  việt_nam tặng lào món quà một_triệu usd mua chuyến thăm chính_thức lào chủ_tịch võ văn thưởng tặng lào món quà trị_giá một_triệu usd củng_cố quan_hệ hữu_nghị vĩ_đại đoàn_kết hợp_tác toàn_diện việt...
# 1296  bốc_thăm tư_pháp xác_minh tài_sản thu_nhập tư_pháp tổ_chức bốc_thăm xác_minh tài_sản thu_nhập quy_định luật phòng_chống tham_nhũng hoạt_động thường_niên tư_pháp tăng_cường minh_bạch trách_nhiệm ch...
# 1297  thủ_tướng giorgia meloni đón trang_trọng chủ_tịch võ văn thưởng trao_đổi toàn_diện hợp_tác thống_nhất biện_pháp thực_chất tăng_cường quan_hệ thủ_tướng giorgia meloni tiềm_năng mở_rộng hợp_tác quyế...
# 1298  chủ_tịch chủ_trì lễ đón tổng_thư_ký liên_hợp_quốc tổng_thư_ký liên_hợp_quốc antónio guterres chuyến thăm chính_thức việt_nam kỷ_niệm việt_nam gia_nhập lhq chuyến thăm việt_nam nhậm_chức tổng_thư_k...
#
#              Label
# 0            False
# 1            False
# 2            False
# 3            False
# 4            False
# ...            ...
# 1294  True-w-false
# 1295  True-w-false
# 1296  True-w-false
# 1297  True-w-false
# 1298  True-w-false
#
# [1216 rows x 2 columns]

# %%
data_shuffled = data.sample(frac=1, random_state=42).reset_index(drop=True)
data_shuffled
# Out:
#                                                                                                                                                                                                       Content  \
# 0     phó chủ_tịch võ thị ánh xuântôi mong_đợi movitel kỳ_tích phó chủ_tịch võ thị ánh xuân bày_tỏ ấn_tượng thành_công viettel mô_hình đầu_tư nước_ngoài mozambiquephó chủ_tịch võ thị ánh xuân làm_việc m...
# 1     vận_động ngân_hàng thương_mại lãi_suất phó thống_đốc nhnn cơ_quan vận_động ngân_hàng thương_mại lãi_suất doanh_nghiệp đẩy_mạnh tín_dụng nămchiều họp_báo chính_phủ thường_kỳ đại_diện ngân_hàng nhà_...
# 2     tài_liệu tố_giác nguyễn_chí vịnh giới_thiệu tài_liệu tố_giác trung_tá vũ trí tước quân_hàm sĩ_quan bbtwebvt— tổng cục ii nỗivũ trítôi quân đảng làm_việc tổng_cục ii quốc_phòng suy_giảm nghiêm_trọn...
# 3     việt bầu lãnh_đạo bang oregon mỹ hiện hạ_nghị_sĩ gốc việt hạ_viện bang oregon thẩm_phán gốc việt việt bầu lãnh_đạo oregon vị_thế việt mỹ chiều giờ_địa_phương thủ_tướng tiếp đoàn chính_trị_gia doan...
# 4     thủ_tướng đề_cao vai_trò asean thế_giới đa cực thủ_tướng dân_số đông sáng_kiến thúc_đẩy asean khả_năng đảm_nhận vị_thế cực thế_giới đa cực vnexpressthủ tướng dân_số đông sáng_kiến thúc_đẩy asean k...
# ...                                                                                                                                                                                                       ...
# 1211  triển_khai loạt dự_án trọng_điểm địa_phương ỷ_lại trung_ương dân_trí thủ_tướng quán_triệt địa_phương vận_động cân_đối nguồn_lực vốn đầu_tư công_trình giao_thông trọng_điểm ỷ_lại trung_ương nội_dun...
# 1212  râu anh_hùng kế_hoạch phản_gián kế_hoạch kế_hoạch phản_gián quy_mô không_gian bố_trí lực_lượng đấu_tranh thắng_lợi giòn_giã đập_tan âm_mưu đánh chiếm chính_quyền lật_đổ chế_độ toán biệt_kích tổ_ch...
# 1213  lãnh_đạo quốc_gia tổ_chức quốc_tế chúc_mừng quốc_khánh việt_nam kỷ_niệm quốc_khánh cộng_hoà_xã_hội_chủ_nghĩa_việt_nam lãnh_đạo quốc_gia tổ_chức quốc_tế gửi chúc_mừng lãnh_đạo đảng nhà_nước việt_na...
# 1214  bộ_chính_trị quyết_định miễn_nhiệm bộ_trưởng tư_pháp lê_thành_long bộ_chính_trị quyết_định miễn_nhiệm bộ_trưởng tư_pháp lê_thành_long vụ tham_nhũng hoạt_động đấu_giá tài_sản nhà_nước thông_tin ban...
# 1215  việt_nam mục_tiêu hình_thành kỹ_sư ngành công_nghiệp bán_dẫn bộ_trưởng khoa_học công_nghệ huỳnh thành_đạt việt_nam mục_tiêu hình_thành kỹ_sư ngành công_nghiệp bán_dẫn phục_vụ phát_triển ngành công...
#
#              Label
# 0             True
# 1             True
# 2            False
# 3     True-w-false
# 4             True
# ...            ...
# 1211  True-w-false
# 1212  True-w-false
# 1213  True-w-false
# 1214  False-w-true
# 1215  True-w-false
#
# [1216 rows x 2 columns]

# %%
sentences = list(data_shuffled['Content'])
labels = list(data_shuffled['Label'])

# %%
import numpy as np
from sklearn.model_selection import train_test_split

# Chia dữ liệu thành tập huấn luyện và tập kiểm tra
X_train, X_test, y_train, y_test = train_test_split(sentences, labels, test_size=0.2, random_state=42, stratify=labels)

# %%
X_train[0]
# Out:
# 'đà_lạt đe_doạ xoá_sổ lịch_sử dốt_nát tận_cùng giới lãnh_đạo hình đà_lạt mẫu tiến_trình công_nghiệp_hoá đô_thị_hoá sapa mẫu thành_công gs trần hữu dũng trang_điểm phẫn_nộ bày_tỏ lãnh_đạo ngu_dốt lãnh_đạo lâm_đồng hề ngu_dốt khôn_ngoan lựa_chọn cty cổ_phần đại quang_minh doanh_nghiệp trấn_giữ khoản đất vàng thủ thiêm phát_sinh dân oan loạt lãnh_đạo hầu bắt_tay doanh_nghiệp quy_hoạch thủ thiêm tức_là đại quang_minh lãnh_đạo lâm_đồng lựa_chọn doanh_nghiệp cáo_già thừa_thãi kinh_nghiệm bất_động_sản ổn_định chính_sách dòng tiền dồi_dào lãnh_đạo lâm_đồng tài_tình quyết_tâm chính_trị lớn_lao chấp_nhận rách_nát rạp hoà_bình biểu_tượng giới lãnh_đạo tỉnh đường_sắt răng_cưa thuỵ_sĩ giá phế_liệu vẽ dự_án phục_hồi ngàn tỷ đồng giới tinh_hoa tỉnh lâm_đồng tinh_thần chỉ_đạo thủ_tướng tiểu paris châu_á rõ_ràng nông_cạn đề_án tiểu paris châu_á đơn_thuần điền chỗ trống gỡ cũ_kỹ mảnh đất vàng kế_hoạch lợi_nhuận doanh_nghiệp việt_nam lố_lăng rác_rưởi hà_nội cạnh hồ gươm hàm cá_mập kiến_trúc thời chắp_vá tư_duy định_hướng xã_hội_chủ_nghĩa lịch_sử đà_lạt chẳng đáng_giá mắt lãnh_đạo tỉnh lâm_đồng choáng_ngợp buộc choáng_ngợp quyết_định ý_nghĩa quy_hoạch chỉnh_trang thiết_kế đầu_tư phát_triển khu_vực trung_tâm tp đà_lạt đoàn văn việt chủ_tịch ubnd tỉnh lâm_đồng nhấn_mạnh lễ công_bố quyết_định quyết_định vĩ_đại đe_doạ xoá_sổ ý_nghĩa gọi đà_lạt yersin dat allis laetitum alliis temperriem nghĩa niềm vui kia mát_lành dàn lãnh_đạo tỉnh tích_cực xoá_bỏ tàn_tích thực_dân phong_kiến thành_phố mộng_mơ hình_thành công_trình đậm chất đặc_trưng cộng_sản thời_đại khẳng_khái thẳng quyết_định nêu mục_tiêu tiến_trình xoá_sổ đà_lạt tạo_lập cộng_sản dựng lá cờ chiến_thắng mảnh đất cao_nguyên kiêu_ngạo sức_mạnh vật_chất chi_phối ý_thức ý_chí chính_trị chinh_phục cải_tạo thiên_nhiên cải_tạo tư_sản san núi lấp biển hạ biến mộng_mơ sương_mù trở_nên quang_đãng đèn_điện dàn cao_tầng nhà_báo mai quốc ấn than_thở facebook thời_đại rực_rỡ u_buồn ấn hiếm sự_kiện tiếng_nói than_thở giận_dữ cay_đắng sự_kiện quyền_lực tham_gia quy_hoạch kêu_gào bảo_tồn sức_mạnh đổi đất hạ_tầng ngu_dốt vô_biên con_người đổi nhiệm_kỳ quyền_lợi đà_lạt sương_mù đà_lạt căm_phẫn tư_duy hợm_hĩnh trọc_phú lãnh_đạo lãnh_đạo đà_lạt tỉnh lâm_đồng người_lớn sống mảnh đất mộng_mơ thản_nhiên tàn_phá đà_lạt đoàn văn việt chủ_tịch ubnd tỉnh lâm_đồng gắn_bó chặt_chẽ đà_lạt cảm_xúc đà_lạt đà_lạt đà_lạt đà_lạt chính_trị chính_trị cơ_chế bắt phục_vụ lợi_quyền đà_lạt mô_hình bêtông gắn điều_hoà thiên_nhiên hiện_thực tâm tầm con_người chính_trị có_lẽ giới lãnh_đạo tỉnh lâm_đồng thực_tâm quyền xoá_bỏ văn_hoá lịch_sử nhân_danh hiện_đại_hoá chờ suy_xét dựa áp_lực dư_luận truyền bi_quan tuyệt_vọng đà_lạt biến cưỡng quy_luật đất hoá kêu_gọi sắm_sửa máy_ảnh gắn thẻ dung_lượng góc phố dốc mái đồi ghi hình_ảnh nay_mai ký_ức'

# %%
y_train[0]
# Out:
# 'False-w-true'

# %%
def label_encoder(labels):
    label_mapping = {'True':0, 'False': 1, 'True-w-false':2, 'False-w-true':3}
    return np.array([label_mapping[label] for label in labels])

# %%
y_train = label_encoder(y_train)
y_test = label_encoder(y_test)

# %%
y_train = np.eye(4)[y_train]
y_test = np.eye(4)[y_test]

# %%
(y_train.shape, y_test.shape)
# Out:
# ((972, 4), (244, 4))

# %% [markdown]
# ## TF-IDF

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# TF-IDF Vectorization
vectorizer = TfidfVectorizer(max_features=10000)
X_train = vectorizer.fit_transform(X_train)
X_test = vectorizer.transform(X_test)

X_train = X_train.toarray()
X_test = X_test.toarray()

(X_train.shape, X_test.shape)
# Out:
# ((972, 10000), (244, 10000))

# %%
X_train = np.reshape(X_train, (X_train.shape[0],1,X_train.shape[1]))
X_test = np.reshape(X_test, (X_test.shape[0],1,X_test.shape[1]))

# %%
(X_train.shape, X_test.shape)
# Out:
# ((972, 1, 10000), (244, 1, 10000))

# %%
# vocab_size = 10000
vector_size = 10000
# max_length = 256

# %% [markdown]
# ## Create model and train

# %% [markdown]
# ### LSTM

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
from tensorflow.keras import regularizers

# defining the LSTM model
model = Sequential(name='LSTM')
# model.add(LSTM(300, input_shape=(1, vector_size)))
model.add(LSTM(300, input_shape=(1, vector_size), return_sequences=True))
model.add(Dropout(0.3))
model.add(LSTM(100))
model.add(Dropout(0.3))
model.add(Dense(300, activation='relu', kernel_regularizer=regularizers.l2(0.3)))
model.add(Dropout(0.3))
model.add(Dense(64, activation='relu', kernel_regularizer=regularizers.l2(0.5)))
model.add(Dropout(0.3))
model.add(Dense(4, activation='softmax'))
model.summary()
# Out:
# Model: "LSTM"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_1 (LSTM)               (None, 1, 300)            12361200
#
#  dropout_3 (Dropout)         (None, 1, 300)            0
#
#  lstm_2 (LSTM)               (None, 100)               160400
#
#  dropout_4 (Dropout)         (None, 100)               0
#
#  dense_3 (Dense)             (None, 300)               30300
#
#  dropout_5 (Dropout)         (None, 300)               0
#
#  dense_4 (Dense)             (None, 64)                19264
#
#  dropout_6 (Dropout)         (None, 64)                0
#
#  dense_5 (Dense)             (None, 4)                 260
#
# =================================================================
# Total params: 12571424 (47.96 MB)
# Trainable params: 12571424 (47.96 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
from keras.utils import plot_model

plot_model(model, show_shapes=True)

# %%
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
history = model.fit(X_train, y_train, epochs=30, batch_size=32, validation_split=0.2)
# Out:
# Epoch 1/30
# 25/25 [==============================] - 14s 358ms/step - loss: 75.2142 - accuracy: 0.2703 - val_loss: 52.4019 - val_accuracy: 0.2769
# Epoch 2/30
# 25/25 [==============================] - 7s 257ms/step - loss: 38.7976 - accuracy: 0.2793 - val_loss: 26.2122 - val_accuracy: 0.2769
# Epoch 3/30
# 25/25 [==============================] - 7s 268ms/step - loss: 19.1539 - accuracy: 0.2960 - val_loss: 12.7717 - val_accuracy: 0.3692
# Epoch 4/30
# 25/25 [==============================] - 8s 312ms/step - loss: 9.3285 - accuracy: 0.4350 - val_loss: 6.2772 - val_accuracy: 0.4513
# Epoch 5/30
# 25/25 [==============================] - 6s 243ms/step - loss: 4.6791 - accuracy: 0.4826 - val_loss: 3.2980 - val_accuracy: 0.4872
# Epoch 6/30
# 25/25 [==============================] - 8s 329ms/step - loss: 2.5649 - accuracy: 0.5071 - val_loss: 1.9812 - val_accuracy: 0.5179
# Epoch 7/30
# 25/25 [==============================] - 7s 279ms/step - loss: 1.6208 - accuracy: 0.5084 - val_loss: 1.4174 - val_accuracy: 0.5282
# Epoch 8/30
# 25/25 [==============================] - 7s 302ms/step - loss: 1.2150 - accuracy: 0.5187 - val_loss: 1.2442 - val_accuracy: 0.5282
# Epoch 9/30
# 25/25 [==============================] - 7s 287ms/step - loss: 1.0218 - accuracy: 0.5547 - val_loss: 1.1462 - val_accuracy: 0.5795
# Epoch 10/30
# 25/25 [==============================] - 6s 257ms/step - loss: 0.9574 - accuracy: 0.5341 - val_loss: 1.1160 - val_accuracy: 0.5385
# Epoch 11/30
# 25/25 [==============================] - 8s 331ms/step - loss: 0.9205 - accuracy: 0.5302 - val_loss: 1.1061 - val_accuracy: 0.5795
# Epoch 12/30
# 25/25 [==============================] - 6s 253ms/step - loss: 0.8850 - accuracy: 0.5830 - val_loss: 1.0971 - val_accuracy: 0.5744
# Epoch 13/30
# 25/25 [==============================] - 9s 357ms/step - loss: 0.8745 - accuracy: 0.5869 - val_loss: 1.0943 - val_accuracy: 0.5795
# Epoch 14/30
# 25/25 [==============================] - 6s 251ms/step - loss: 0.8536 - accuracy: 0.6371 - val_loss: 1.1082 - val_accuracy: 0.5590
# Epoch 15/30
# 25/25 [==============================] - 7s 296ms/step - loss: 0.8407 - accuracy: 0.6551 - val_loss: 1.1010 - val_accuracy: 0.5641
# Epoch 16/30
# 25/25 [==============================] - 7s 292ms/step - loss: 0.8240 - accuracy: 0.6847 - val_loss: 1.1015 - val_accuracy: 0.5744
# Epoch 17/30
# 25/25 [==============================] - 6s 252ms/step - loss: 0.8251 - accuracy: 0.6976 - val_loss: 1.0806 - val_accuracy: 0.5692
# Epoch 18/30
# 25/25 [==============================] - 8s 335ms/step - loss: 0.7949 - accuracy: 0.7156 - val_loss: 1.1123 - val_accuracy: 0.5487
# Epoch 19/30
# 25/25 [==============================] - 6s 248ms/step - loss: 0.7677 - accuracy: 0.7529 - val_loss: 1.0984 - val_accuracy: 0.5795
# Epoch 20/30
# 25/25 [==============================] - 8s 324ms/step - loss: 0.7558 - accuracy: 0.7246 - val_loss: 1.1185 - val_accuracy: 0.5795
# Epoch 21/30
# 25/25 [==============================] - 6s 255ms/step - loss: 0.7436 - accuracy: 0.7477 - val_loss: 1.1154 - val_accuracy: 0.5949
# Epoch 22/30
# 25/25 [==============================] - 7s 290ms/step - loss: 0.7219 - accuracy: 0.7593 - val_loss: 1.1258 - val_accuracy: 0.5795
# Epoch 23/30
# 25/25 [==============================] - 7s 296ms/step - loss: 0.7008 - accuracy: 0.7529 - val_loss: 1.1520 - val_accuracy: 0.5795
# Epoch 24/30
# 25/25 [==============================] - 7s 296ms/step - loss: 0.6908 - accuracy: 0.7490 - val_loss: 1.1477 - val_accuracy: 0.6000
# Epoch 25/30
# 25/25 [==============================] - 10s 400ms/step - loss: 0.6849 - accuracy: 0.7542 - val_loss: 1.1398 - val_accuracy: 0.5744
# Epoch 26/30
# 25/25 [==============================] - 6s 246ms/step - loss: 0.6839 - accuracy: 0.7658 - val_loss: 1.1524 - val_accuracy: 0.5744
# Epoch 27/30
# 25/25 [==============================] - 8s 316ms/step - loss: 0.6726 - accuracy: 0.7761 - val_loss: 1.1587 - val_accuracy: 0.6000
# Epoch 28/30
# 25/25 [==============================] - 7s 283ms/step - loss: 0.6686 - accuracy: 0.7889 - val_loss: 1.1630 - val_accuracy: 0.5641
# Epoch 29/30
# 25/25 [==============================] - 6s 253ms/step - loss: 0.6585 - accuracy: 0.7786 - val_loss: 1.1962 - val_accuracy: 0.5795
# Epoch 30/30
# 25/25 [==============================] - 8s 329ms/step - loss: 0.6574 - accuracy: 0.8018 - val_loss: 1.2045 - val_accuracy: 0.5897

# %%
import matplotlib.pyplot as plt

def plot_graphs(history, metric):
    plt.plot(history.history[metric])
    plt.plot(history.history['val_'+metric], '')
    plt.xlabel("Epochs")
    plt.ylabel(metric)
    plt.legend([metric, 'val_'+metric])

plt.figure(figsize=(16, 8))
plt.subplot(1, 2, 1)
plot_graphs(history, 'accuracy')
plt.ylim(None, 1)
plt.subplot(1, 2, 2)
plot_graphs(history, 'loss')
plt.ylim(0, None)
# Out:
# (0.0, 78.9420743316412)

# %%
import itertools
import matplotlib.pyplot as plt

def plot_confusion_matrix(cm, class_names):
    plt.imshow(cm, interpolation='nearest', cmap=plt.cm.Blues)
    plt.title("Confusion matrix")
    plt.colorbar()
    tick_marks = np.arange(len(class_names))
    plt.xticks(tick_marks, class_names, rotation=45)
    plt.yticks(tick_marks, class_names)

    # Compute the labels from the normalized confusion matrix.
    labels = np.around(cm.astype('float') / cm.sum(axis=1)[:, np.newaxis], decimals=2)

    # Use white text if squares are dark; otherwise black.
    threshold = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        color = "white" if cm[i, j] > threshold else "black"
        plt.text(j, i, labels[i, j], horizontalalignment="center", color=color)

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.show()
class_names = ['True', 'False', 'True-w-false', 'False-w-true']

# %%
from sklearn.metrics import confusion_matrix

y_pred = model.predict(X_test)
y_pred = np.argmax(y_pred, axis=1)
cm = confusion_matrix(np.argmax(y_test, axis=1), y_pred)

plot_confusion_matrix(cm, class_names)
# Out:
# 8/8 [==============================] - 1s 29ms/step

# %%
test_loss, test_acc = model.evaluate(X_test, y_test)

print('Test Loss:', test_loss)
print('Test Accuracy:', test_acc)
# Out:
# 8/8 [==============================] - 0s 28ms/step - loss: 1.2891 - accuracy: 0.5697
# Test Loss: 1.2890617847442627
# Test Accuracy: 0.5696721076965332

# %%
from sklearn.metrics import classification_report

# Predict on the train set
y_pred = model.predict(X_train)
y_pred = np.argmax(y_pred, axis=1)

# Evaluate the classifier
print(classification_report(np.argmax(y_train, axis=1), y_pred))
# Out:
# 31/31 [==============================] - 1s 29ms/step
#               precision    recall  f1-score   support
#
#            0       0.64      0.93      0.76       273
#            1       0.97      0.93      0.95       230
#            2       0.82      0.32      0.46       235
#            3       0.85      0.94      0.89       234
#
#     accuracy                           0.79       972
#    macro avg       0.82      0.78      0.76       972
# weighted avg       0.81      0.79      0.76       972

# %%
from sklearn.metrics import classification_report

# Predict on the test set
y_pred = model.predict(X_test)
y_pred = np.argmax(y_pred, axis=1)

# Evaluate the classifier
print(classification_report(np.argmax(y_test, axis=1), y_pred))
# Out:
# 8/8 [==============================] - 0s 27ms/step
#               precision    recall  f1-score   support
#
#            0       0.59      0.61      0.60        69
#            1       0.82      0.62      0.71        58
#            2       0.47      0.29      0.36        59
#            3       0.47      0.76      0.58        58
#
#     accuracy                           0.57       244
#    macro avg       0.59      0.57      0.56       244
# weighted avg       0.59      0.57      0.56       244

# %% [markdown]
# ### GRU

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import GRU, Dense, Dropout
from tensorflow.keras import regularizers

# defining the GRU model
model = Sequential(name='GRU')
model.add(GRU(300, input_shape=(1, vector_size)))
model.add(Dropout(0.3))
model.add(Dense(300, activation='relu', kernel_regularizer=regularizers.l2(0.3)))
model.add(Dropout(0.3))
model.add(Dense(64, activation='relu', kernel_regularizer=regularizers.l2(0.5)))
model.add(Dropout(0.3))
model.add(Dense(4, activation='softmax'))
model.summary()
# Out:
# Model: "GRU"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  gru_1 (GRU)                 (None, 300)               541800
#
#  dropout_3 (Dropout)         (None, 300)               0
#
#  dense_3 (Dense)             (None, 300)               90300
#
#  dropout_4 (Dropout)         (None, 300)               0
#
#  dense_4 (Dense)             (None, 64)                19264
#
#  dropout_5 (Dropout)         (None, 64)                0
#
#  dense_5 (Dense)             (None, 4)                 260
#
# =================================================================
# Total params: 651624 (2.49 MB)
# Trainable params: 651624 (2.49 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
history = model.fit(X_train, y_train, epochs=30, batch_size=32, validation_split=0.2)

# %%
import matplotlib.pyplot as plt

def plot_graphs(history, metric):
    plt.plot(history.history[metric])
    plt.plot(history.history['val_'+metric], '')
    plt.xlabel("Epochs")
    plt.ylabel(metric)
    plt.legend([metric, 'val_'+metric])

plt.figure(figsize=(16, 8))
plt.subplot(1, 2, 1)
plot_graphs(history, 'accuracy')
plt.ylim(None, 1)
plt.subplot(1, 2, 2)
plot_graphs(history, 'loss')
plt.ylim(0, None)

# %%
test_loss, test_acc = model.evaluate(X_test, y_test)

print('Test Loss:', test_loss)
print('Test Accuracy:', test_acc)

# %%
from sklearn.metrics import classification_report

# Predict on the train set
y_pred = model.predict(X_train)
y_pred = np.argmax(y_pred, axis=1)

# Evaluate the classifier
print(classification_report(np.argmax(y_train, axis=1), y_pred))

# %%
from sklearn.metrics import classification_report

# Predict on the test set
y_pred = model.predict(X_test)
y_pred = np.argmax(y_pred, axis=1)

# Evaluate the classifier
print(classification_report(np.argmax(y_test, axis=1), y_pred))

# %% [markdown]
# ### Bi-LSTM

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Bidirectional

model = Sequential(name='Bidirectional_LSTM')
model.add(Bidirectional(LSTM(100), input_shape=(1, vector_size)))
model.add(Dropout(0.3))
model.add(Dense(100, activation='relu', kernel_regularizer=regularizers.l1_l2()))
model.add(Dropout(0.3))
model.add(Dense(4, activation='softmax'))
model.summary()
# Out:
# Model: "Bidirectional_LSTM"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional (Bidirection  (None, 200)               8080800
#  al)
#
#  dropout_3 (Dropout)         (None, 200)               0
#
#  dense_3 (Dense)             (None, 100)               20100
#
#  dropout_4 (Dropout)         (None, 100)               0
#
#  dense_4 (Dense)             (None, 4)                 404
#
# =================================================================
# Total params: 8101304 (30.90 MB)
# Trainable params: 8101304 (30.90 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
from keras.utils import plot_model

plot_model(model, show_shapes=True)

# %%
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
history = model.fit(X_train, y_train, epochs=50, batch_size=32, validation_split=0.2)
# Out:
# Epoch 1/50
# 25/25 [==============================] - 8s 155ms/step - loss: 14.3491 - accuracy: 0.3166 - val_loss: 11.6938 - val_accuracy: 0.4154
# Epoch 2/50
# 25/25 [==============================] - 4s 147ms/step - loss: 9.7271 - accuracy: 0.4157 - val_loss: 7.6849 - val_accuracy: 0.4615
# Epoch 3/50
# 25/25 [==============================] - 4s 158ms/step - loss: 6.2112 - accuracy: 0.5341 - val_loss: 4.7422 - val_accuracy: 0.4821
# Epoch 4/50
# 25/25 [==============================] - 3s 116ms/step - loss: 3.7309 - accuracy: 0.5161 - val_loss: 2.7893 - val_accuracy: 0.4821
# Epoch 5/50
# 25/25 [==============================] - 3s 110ms/step - loss: 2.2122 - accuracy: 0.4968 - val_loss: 1.7400 - val_accuracy: 0.4923
# Epoch 6/50
# 25/25 [==============================] - 3s 109ms/step - loss: 1.5317 - accuracy: 0.5006 - val_loss: 1.4275 - val_accuracy: 0.4923
# Epoch 7/50
# 25/25 [==============================] - 3s 112ms/step - loss: 1.3761 - accuracy: 0.4839 - val_loss: 1.3492 - val_accuracy: 0.5128
# Epoch 8/50
# 25/25 [==============================] - 4s 159ms/step - loss: 1.3021 - accuracy: 0.4878 - val_loss: 1.2856 - val_accuracy: 0.5179
# Epoch 9/50
# 25/25 [==============================] - 4s 158ms/step - loss: 1.2408 - accuracy: 0.5135 - val_loss: 1.2418 - val_accuracy: 0.5231
# Epoch 10/50
# 25/25 [==============================] - 3s 108ms/step - loss: 1.1969 - accuracy: 0.5354 - val_loss: 1.2076 - val_accuracy: 0.5231
# Epoch 11/50
# 25/25 [==============================] - 3s 108ms/step - loss: 1.1424 - accuracy: 0.5779 - val_loss: 1.1850 - val_accuracy: 0.5077
# Epoch 12/50
# 25/25 [==============================] - 3s 109ms/step - loss: 1.1011 - accuracy: 0.6165 - val_loss: 1.1666 - val_accuracy: 0.5538
# Epoch 13/50
# 25/25 [==============================] - 4s 145ms/step - loss: 1.0528 - accuracy: 0.6461 - val_loss: 1.1518 - val_accuracy: 0.5436
# Epoch 14/50
# 25/25 [==============================] - 4s 151ms/step - loss: 1.0036 - accuracy: 0.6782 - val_loss: 1.1392 - val_accuracy: 0.5846
# Epoch 15/50
# 25/25 [==============================] - 3s 116ms/step - loss: 0.9637 - accuracy: 0.7079 - val_loss: 1.1316 - val_accuracy: 0.5846
# Epoch 16/50
# 25/25 [==============================] - 3s 108ms/step - loss: 0.9203 - accuracy: 0.7297 - val_loss: 1.1191 - val_accuracy: 0.6000
# Epoch 17/50
# 25/25 [==============================] - 3s 108ms/step - loss: 0.8880 - accuracy: 0.7387 - val_loss: 1.1073 - val_accuracy: 0.6051
# Epoch 18/50
# 25/25 [==============================] - 3s 113ms/step - loss: 0.8408 - accuracy: 0.7696 - val_loss: 1.0998 - val_accuracy: 0.5949
# Epoch 19/50
# 25/25 [==============================] - 4s 158ms/step - loss: 0.8212 - accuracy: 0.7606 - val_loss: 1.0893 - val_accuracy: 0.6103
# Epoch 20/50
# 25/25 [==============================] - 4s 144ms/step - loss: 0.7810 - accuracy: 0.7864 - val_loss: 1.0729 - val_accuracy: 0.6205
# Epoch 21/50
# 25/25 [==============================] - 3s 106ms/step - loss: 0.7591 - accuracy: 0.8314 - val_loss: 1.0617 - val_accuracy: 0.6308
# Epoch 22/50
# 25/25 [==============================] - 3s 109ms/step - loss: 0.7474 - accuracy: 0.8198 - val_loss: 1.0523 - val_accuracy: 0.6256
# Epoch 23/50
# 25/25 [==============================] - 3s 109ms/step - loss: 0.7143 - accuracy: 0.8250 - val_loss: 1.0432 - val_accuracy: 0.6410
# Epoch 24/50
# 25/25 [==============================] - 3s 130ms/step - loss: 0.6914 - accuracy: 0.8507 - val_loss: 1.0342 - val_accuracy: 0.6513
# Epoch 25/50
# 25/25 [==============================] - 4s 152ms/step - loss: 0.6800 - accuracy: 0.8764 - val_loss: 1.0288 - val_accuracy: 0.6462
# Epoch 26/50
# 25/25 [==============================] - 3s 134ms/step - loss: 0.6609 - accuracy: 0.8906 - val_loss: 1.0190 - val_accuracy: 0.6718
# Epoch 27/50
# 25/25 [==============================] - 3s 111ms/step - loss: 0.6331 - accuracy: 0.9060 - val_loss: 1.0170 - val_accuracy: 0.6667
# Epoch 28/50
# 25/25 [==============================] - 3s 114ms/step - loss: 0.6032 - accuracy: 0.9447 - val_loss: 1.0121 - val_accuracy: 0.6769
# Epoch 29/50
# 25/25 [==============================] - 3s 111ms/step - loss: 0.5832 - accuracy: 0.9459 - val_loss: 1.0061 - val_accuracy: 0.6974
# Epoch 30/50
# 25/25 [==============================] - 4s 154ms/step - loss: 0.5624 - accuracy: 0.9588 - val_loss: 1.0051 - val_accuracy: 0.6872
# Epoch 31/50
# 25/25 [==============================] - 4s 159ms/step - loss: 0.5300 - accuracy: 0.9768 - val_loss: 1.0034 - val_accuracy: 0.6872
# Epoch 32/50
# 25/25 [==============================] - 3s 109ms/step - loss: 0.5185 - accuracy: 0.9653 - val_loss: 1.0056 - val_accuracy: 0.6872
# Epoch 33/50
# 25/25 [==============================] - 3s 109ms/step - loss: 0.4919 - accuracy: 0.9755 - val_loss: 0.9948 - val_accuracy: 0.6769
# Epoch 34/50
# 25/25 [==============================] - 3s 109ms/step - loss: 0.4871 - accuracy: 0.9768 - val_loss: 1.0001 - val_accuracy: 0.6872
# Epoch 35/50
# 25/25 [==============================] - 3s 123ms/step - loss: 0.4705 - accuracy: 0.9781 - val_loss: 0.9969 - val_accuracy: 0.6821
# Epoch 36/50
# 25/25 [==============================] - 4s 161ms/step - loss: 0.4461 - accuracy: 0.9807 - val_loss: 0.9939 - val_accuracy: 0.6718
# Epoch 37/50
# 25/25 [==============================] - 3s 134ms/step - loss: 0.4328 - accuracy: 0.9833 - val_loss: 0.9928 - val_accuracy: 0.6769
# Epoch 38/50
# 25/25 [==============================] - 3s 109ms/step - loss: 0.4231 - accuracy: 0.9781 - val_loss: 0.9940 - val_accuracy: 0.6872
# Epoch 39/50
# 25/25 [==============================] - 3s 109ms/step - loss: 0.4174 - accuracy: 0.9897 - val_loss: 0.9906 - val_accuracy: 0.6923
# Epoch 40/50
# 25/25 [==============================] - 3s 108ms/step - loss: 0.4158 - accuracy: 0.9794 - val_loss: 0.9896 - val_accuracy: 0.6974
# Epoch 41/50
# 25/25 [==============================] - 4s 146ms/step - loss: 0.3964 - accuracy: 0.9794 - val_loss: 0.9889 - val_accuracy: 0.6923
# Epoch 42/50
# 25/25 [==============================] - 4s 157ms/step - loss: 0.4025 - accuracy: 0.9781 - val_loss: 0.9914 - val_accuracy: 0.6974
# Epoch 43/50
# 25/25 [==============================] - 3s 115ms/step - loss: 0.3883 - accuracy: 0.9858 - val_loss: 0.9715 - val_accuracy: 0.7077
# Epoch 44/50
# 25/25 [==============================] - 3s 111ms/step - loss: 0.3740 - accuracy: 0.9846 - val_loss: 0.9761 - val_accuracy: 0.7128
# Epoch 45/50
# 25/25 [==============================] - 3s 108ms/step - loss: 0.3696 - accuracy: 0.9897 - val_loss: 0.9745 - val_accuracy: 0.7128
# Epoch 46/50
# 25/25 [==============================] - 3s 120ms/step - loss: 0.3620 - accuracy: 0.9884 - val_loss: 0.9722 - val_accuracy: 0.7077
# Epoch 47/50
# 25/25 [==============================] - 4s 152ms/step - loss: 0.3583 - accuracy: 0.9807 - val_loss: 0.9760 - val_accuracy: 0.7179
# Epoch 48/50
# 25/25 [==============================] - 4s 144ms/step - loss: 0.3598 - accuracy: 0.9820 - val_loss: 0.9724 - val_accuracy: 0.7231
# Epoch 49/50
# 25/25 [==============================] - 3s 108ms/step - loss: 0.3477 - accuracy: 0.9923 - val_loss: 0.9684 - val_accuracy: 0.7128
# Epoch 50/50
# 25/25 [==============================] - 3s 109ms/step - loss: 0.3430 - accuracy: 0.9897 - val_loss: 0.9649 - val_accuracy: 0.7179

# %%
import matplotlib.pyplot as plt

def plot_graphs(history, metric):
    plt.plot(history.history[metric])
    plt.plot(history.history['val_'+metric], '')
    plt.xlabel("Epochs")
    plt.ylabel(metric)
    plt.legend([metric, 'val_'+metric])

plt.figure(figsize=(16, 8))
plt.subplot(1, 2, 1)
plot_graphs(history, 'accuracy')
plt.ylim(None, 1)
plt.subplot(1, 2, 2)
plot_graphs(history, 'loss')
plt.ylim(0, None)
# Out:
# (0.0, 15.049400733411312)

# %%
test_loss, test_acc = model.evaluate(X_test, y_test)

print('Test Loss:', test_loss)
print('Test Accuracy:', test_acc)
# Out:
# 8/8 [==============================] - 0s 30ms/step - loss: 1.2406 - accuracy: 0.6434
# Test Loss: 1.2406195402145386
# Test Accuracy: 0.6434426307678223

# %%
from sklearn.metrics import classification_report

# Predict on the train set
y_pred = model.predict(X_train)
y_pred = np.argmax(y_pred, axis=1)

# Evaluate the classifier
print(classification_report(np.argmax(y_train, axis=1), y_pred))
# Out:
# 31/31 [==============================] - 1s 20ms/step
#               precision    recall  f1-score   support
#
#            0       0.97      0.93      0.95       273
#            1       0.94      0.98      0.96       230
#            2       0.89      0.93      0.91       235
#            3       0.97      0.93      0.95       234
#
#     accuracy                           0.94       972
#    macro avg       0.94      0.94      0.94       972
# weighted avg       0.94      0.94      0.94       972

# %%
from sklearn.metrics import classification_report

# Predict on the test set
y_pred = model.predict(X_test)
y_pred = np.argmax(y_pred, axis=1)

# Evaluate the classifier
print(classification_report(np.argmax(y_test, axis=1), y_pred))
# Out:
# 8/8 [==============================] - 0s 43ms/step
#               precision    recall  f1-score   support
#
#            0       0.71      0.59      0.65        69
#            1       0.77      0.84      0.80        58
#            2       0.50      0.59      0.54        59
#            3       0.62      0.55      0.58        58
#
#     accuracy                           0.64       244
#    macro avg       0.65      0.65      0.64       244
# weighted avg       0.65      0.64      0.64       244

# %% [markdown]
# ## Save to drive

# %%
from google.colab import drive
drive.mount("/content/MyDrive")
# Out:
# Mounted at /content/MyDrive

# %%
# Lưu model
model.save('/content/MyDrive/MyDrive/Colab Notebooks/Fake news detection/model/lstm_tfidf_4_class.h5')
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
